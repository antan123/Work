# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def load_file_from_excel(file_path):
    df = pd.ExcelFile(file_path)
    df = pd.read_excel(df, df.sheet_names[0])
    return df

# %%
greedy= load_file_from_excel("/Users/nitya/Downloads/PythonForDataScience-master/data/ID_counts.xlsx")

# %%
greedy=greedy[(greedy['impressions'] > 500)]

# %%
ID=greedy['id']

# %%
ID.to_csv('data/ID.csv')

# %%
counts=greedy['impressions'].as_matrix()

# %%
values=greedy['CTR'].as_matrix()

# %%
bandit_probs = values  # bandit probabilities of success
N_experiments = 50  # number of experiments to perform
N_episodes = 10000  # number of episodes per experiment
epsilon = 0.5  # probability of random exploration (fraction)
save_fig = True  # if false -> plot, if true save as file in same directory
save_format = ".png"  # ".pdf" or ".png"

# %%
class Bandit:
    def __init__(self, bandit_probs):
        self.N = len(bandit_probs)  # number of bandits
        self.prob = bandit_probs  # success probabilities for each bandit
    # Get reward (1 for success, 0 for failure)
    def get_reward(self, action):
        rand = np.random.random()  # [0.0,1.0)
        reward = 1 if (rand < self.prob[action]) else 0
        return reward

# %%
class Agent:
        def __init__(self, bandit, epsilon):
            self.epsilon = epsilon
            self.k = np.zeros(bandit.N, dtype=np.int)  # number of times action was chosen
            self.Q = np.zeros(bandit.N, dtype=np.float)  # estimated value
        # Update Q action-value using:
        # Q(a) <- Q(a) + 1/(k+1) * (r(a) - Q(a))
        def update_Q(self, action, reward):
            self.k[action] += 1  # update action counter k -> k+1
            self.Q[action] += (1./self.k[action]) * (reward - self.Q[action])
        # Choose action using an epsilon-greedy agent
        def choose_action(self, bandit, force_explore=False):
            rand = np.random.random()  # [0.0,1.0)
            if (rand < self.epsilon) or force_explore:
                action_explore = np.random.randint(bandit.N)  # explore random bandit
                return action_explore
            else:
                #action_greedy = np.argmax(self.Q)  # exploit best current bandit
                action_greedy = np.random.choice(np.flatnonzero(self.Q == self.Q.max()))
                return action_greedy

# %%
def experiment(agent, bandit, N_episodes):
    action_history = []
    reward_history = []
    for episode in range(N_episodes):
        # Choose action from agent (from current Q estimate)
        action = agent.choose_action(bandit)
        # Pick up reward from bandit for chosen action
        reward = bandit.get_reward(action)
        # Update Q action-value estimates
        agent.update_Q(action, reward)
        # Append to history
        action_history.append(action)
        reward_history.append(reward)
    return (np.array(action_history), np.array(reward_history))

# %%
N_bandits = len(bandit_probs)
print("Running multi-armed bandits with N_bandits = {} and agent epsilon = {}".format(N_bandits, epsilon))
reward_history_avg = np.zeros(N_episodes)  # reward history experiment-averaged
action_history_sum = np.zeros((N_episodes, N_bandits))  # sum action history
for i in range(N_experiments):
    bandit = Bandit(bandit_probs)  # initialize bandits
    agent = Agent(bandit, epsilon)  # initialize agent
    (action_history, reward_history) = experiment(agent, bandit, N_episodes)  # perform experiment
    print("[Experiment {}/{}]".format(i + 1, N_experiments))
    print("  N_episodes = {}".format(N_episodes))
    print("  bandit choice history = {}".format(action_history + 1))
    print("  reward history = {}".format(reward_history))
    print("  average reward = {}".format(np.sum(reward_history) / len(reward_history)))
    print("")
        # Sum up experiment reward (later to be divided to represent an average)
reward_history_avg += reward_history
        # Sum up action history
for j, (a) in enumerate(action_history):
    action_history_sum[j][a] += 1
reward_history_avg /= np.float(N_experiments)
print("reward history avg = {}".format(reward_history_avg))
# Out:
# Running multi-armed bandits with N_bandits = 1338 and agent epsilon = 0.5
# [Experiment 1/50]
#   N_episodes = 10000
#   bandit choice history = [  64  806  975 ...  900 1065 1338]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0205
#
# [Experiment 2/50]
#   N_episodes = 10000
#   bandit choice history = [ 708  129  129 ... 1338 1338  307]
#   reward history = [0 1 0 ... 0 0 0]
#   average reward = 0.0208
#
# [Experiment 3/50]
#   N_episodes = 10000
#   bandit choice history = [  38  738 1044 ... 1264 1264  877]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0068
#
# [Experiment 4/50]
#   N_episodes = 10000
#   bandit choice history = [1213   19  171 ... 1338   22 1338]
#   reward history = [0 0 0 ... 1 0 0]
#   average reward = 0.027
#
# [Experiment 5/50]
#   N_episodes = 10000
#   bandit choice history = [1154  440  685 ... 1160  256  834]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0092
#
# [Experiment 6/50]
#   N_episodes = 10000
#   bandit choice history = [1024  761  329 ...  950  172 1084]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0105
#
# [Experiment 7/50]
#   N_episodes = 10000
#   bandit choice history = [877 417 660 ... 105 123 465]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0109
#
# [Experiment 8/50]
#   N_episodes = 10000
#   bandit choice history = [ 536  916 1093 ...  882 1307  246]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0117
#
# [Experiment 9/50]
#   N_episodes = 10000
#   bandit choice history = [ 359 1109  881 ... 1163 1163 1163]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0175
#
# [Experiment 10/50]
#   N_episodes = 10000
#   bandit choice history = [ 761 1117  219 ...  964  362 1040]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0142
#
# [Experiment 11/50]
#   N_episodes = 10000
#   bandit choice history = [  67  401  265 ... 1070  250 1070]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0126
#
# [Experiment 12/50]
#   N_episodes = 10000
#   bandit choice history = [  36  329   61 ... 1103  712  244]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0141
#
# [Experiment 13/50]
#   N_episodes = 10000
#   bandit choice history = [ 743 1211   29 ...  465 1338 1338]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0328
#
# [Experiment 14/50]
#   N_episodes = 10000
#   bandit choice history = [ 739  422  423 ...  592  592 1160]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0104
#
# [Experiment 15/50]
#   N_episodes = 10000
#   bandit choice history = [ 481  152  561 ... 1338 1338  468]
#   reward history = [0 0 0 ... 0 1 0]
#   average reward = 0.0291
#
# [Experiment 16/50]
#   N_episodes = 10000
#   bandit choice history = [ 897 1051  722 ... 1338  929 1338]
#   reward history = [0 0 0 ... 0 0 1]
#   average reward = 0.0326
#
# [Experiment 17/50]
#   N_episodes = 10000
#   bandit choice history = [ 270  984  372 ...  233   94 1086]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0094
#
# [Experiment 18/50]
#   N_episodes = 10000
#   bandit choice history = [ 204 1304  473 ... 1060  439 1338]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0298
#
# [Experiment 19/50]
#   N_episodes = 10000
#   bandit choice history = [ 865  761  865 ... 1338 1338  918]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0294
#
# [Experiment 20/50]
#   N_episodes = 10000
#   bandit choice history = [ 953  401  318 ...  672 1176  206]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0136
#
# [Experiment 21/50]
#   N_episodes = 10000
#   bandit choice history = [1241  910  350 ...  107 1063 1242]
#   reward history = [0 0 0 ... 0 0 1]
#   average reward = 0.0107
#
# [Experiment 22/50]
#   N_episodes = 10000
#   bandit choice history = [ 771  705  403 ... 1178  852 1266]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.013
#
# [Experiment 23/50]
#   N_episodes = 10000
#   bandit choice history = [319 917 546 ... 565 547 723]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0321
#
# [Experiment 24/50]
#   N_episodes = 10000
#   bandit choice history = [1214  613  331 ...  649  900   47]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.012
#
# [Experiment 25/50]
#   N_episodes = 10000
#   bandit choice history = [ 603  870  151 ...  184  184 1276]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0088
#
# [Experiment 26/50]
#   N_episodes = 10000
#   bandit choice history = [1100 1024 1294 ...  927  927  346]
#   reward history = [0 0 0 ... 1 0 0]
#   average reward = 0.0354
#
# [Experiment 27/50]
#   N_episodes = 10000
#   bandit choice history = [ 904  274 1062 ... 1338  270 1338]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0239
#
# [Experiment 28/50]
#   N_episodes = 10000
#   bandit choice history = [1320  438  337 ...  803 1021  647]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0116
#
# [Experiment 29/50]
#   N_episodes = 10000
#   bandit choice history = [ 911 1015  516 ...  397 1338 1338]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0209
#
# [Experiment 30/50]
#   N_episodes = 10000
#   bandit choice history = [ 754 1081  604 ...  414 1137  967]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0117
#
# [Experiment 31/50]
#   N_episodes = 10000
#   bandit choice history = [ 826  360  665 ...  284 1110 1324]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0127
#
# [Experiment 32/50]
#   N_episodes = 10000
#   bandit choice history = [ 285  975 1054 ... 1158 1112 1158]
#   reward history = [0 0 0 ... 1 0 0]
#   average reward = 0.0124
#
# [Experiment 33/50]
#   N_episodes = 10000
#   bandit choice history = [ 377  435   21 ... 1158 1158 1158]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0128
#
# [Experiment 34/50]
#   N_episodes = 10000
#   bandit choice history = [827 954 519 ... 889 725 924]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0096
#
# [Experiment 35/50]
#   N_episodes = 10000
#   bandit choice history = [ 871 1279  948 ... 1241  407  947]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0087
#
# [Experiment 36/50]
#   N_episodes = 10000
#   bandit choice history = [ 942 1060 1062 ... 1124  936   87]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0112
#
# [Experiment 37/50]
#   N_episodes = 10000
#   bandit choice history = [ 129 1197  844 ...  571  571  786]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0105
#
# [Experiment 38/50]
#   N_episodes = 10000
#   bandit choice history = [ 365  446 1064 ...  421 1163 1260]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0096
#
# [Experiment 39/50]
#   N_episodes = 10000
#   bandit choice history = [ 707  844  891 ... 1238  956  403]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0122
#
# [Experiment 40/50]
#   N_episodes = 10000
#   bandit choice history = [ 892 1018   54 ... 1163  597 1163]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0143
#
# [Experiment 41/50]
#   N_episodes = 10000
#   bandit choice history = [782 749 264 ...  30 472 497]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0098
#
# [Experiment 42/50]
#   N_episodes = 10000
#   bandit choice history = [ 173  451  668 ... 1338 1338  265]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0216
#
# [Experiment 43/50]
#   N_episodes = 10000
#   bandit choice history = [ 784  192  589 ... 1005  568 1005]
#   reward history = [0 0 0 ... 1 0 0]
#   average reward = 0.0098
#
# [Experiment 44/50]
#   N_episodes = 10000
#   bandit choice history = [ 137  276 1111 ... 1172  240 1172]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0087
#
# [Experiment 45/50]
#   N_episodes = 10000
#   bandit choice history = [ 820  650  890 ... 1176  627  874]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0133
#
# [Experiment 46/50]
#   N_episodes = 10000
#   bandit choice history = [455 784 562 ... 644 167 305]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0161
#
# [Experiment 47/50]
#   N_episodes = 10000
#   bandit choice history = [ 378  833 1186 ... 1338 1100 1338]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0242
#
# [Experiment 48/50]
#   N_episodes = 10000
#   bandit choice history = [ 721  495  295 ... 1093  944  228]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0108
#
# [Experiment 49/50]
#   N_episodes = 10000
#   bandit choice history = [824 834 593 ... 625 625 241]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0115
#
# [Experiment 50/50]
#   N_episodes = 10000
#   bandit choice history = [ 461  351 1300 ...   29  997 1338]
#   reward history = [0 0 0 ... 0 0 0]
#   average reward = 0.0317
#
# reward history avg = [0. 0. 0. ... 0. 0. 0.]

# %%
plt.plot(reward_history_avg)
plt.xlabel("Episode number")
plt.ylabel("Rewards collected".format(N_experiments))
plt.title("Bandit reward history averaged over {} experiments (epsilon = {})".format(N_experiments, epsilon))
ax = plt.gca()
ax.set_xscale("log", nonposx='clip')
plt.xlim([1, N_episodes])
plt.show()

# %%
# Plot action history results
plt.figure(figsize=(18, 12))
for i in range(N_bandits):
    action_history_sum_plot = 100 * action_history_sum[:,i] / N_experiments
    plt.plot(list(np.array(range(len(action_history_sum_plot)))+1),action_history_sum_plot,
             linewidth=5.0,
    label="Bandit #{}".format(i+1))
plt.title("Bandit action history averaged over {} experiments (epsilon = {})".format(N_experiments, epsilon), fontsize=26)
plt.xlabel("Episode Number", fontsize=26)
plt.ylabel("Bandit Action Choices (%)", fontsize=26)
leg = plt.legend(loc='upper left', shadow=True, fontsize=4)
ax = plt.gca()
ax.set_xscale("log", nonposx='clip')
plt.xlim([1, N_episodes])
plt.ylim([0, 100])
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
for legobj in leg.legendHandles:
    legobj.set_linewidth(16.0)
plt.show()

# %%
print("bandit choice history = {}".format(action_history ))
# Out:
#   bandit choice history = [357 930 938 ... 932 932 442]

# %%
bandit_selection=action_history+1
df = pd.DataFrame(bandit_selection)

# %%
df.to_csv('data/ratio_EG.csv')

# %%
bandit_selection=reward_history
df1= pd.DataFrame(bandit_selection)

# %%
df1.to_csv('data/EG.csv')

# %%
ratio= load_file_from_excel("/Users/nitya/Downloads/PythonForDataScience-master/data/ratio_EG.xlsx")

# %%
ratio.columns
# Out:
# Index(['ID_selected'], dtype='object')

# %%
ratio1=ratio['ID_selected'].value_counts()

# %%
ratio1.to_csv('data/ratio1_EG.csv')

# %%
reward=ratio['reward'].value_counts()

# %%
reward
# Out:
# 0    1305
# 1      33
# Name: reward, dtype: int64
